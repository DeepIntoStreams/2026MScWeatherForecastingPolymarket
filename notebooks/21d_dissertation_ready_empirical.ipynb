# %% [markdown]
# # 21d dissertation-ready empirical consolidation
#
# This notebook wraps the Terminal-ready 21d script and consolidates the final Hong Kong empirical results without changing any model or trading specification.

# %%
from pathlib import Path
import subprocess, sys
cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == 'notebooks' else cwd
script = repo_root / 'scripts' / '21d_dissertation_ready_empirical.py'
subprocess.run([sys.executable, str(script), '--repo-root', str(repo_root)], check=True)

# %%
import pandas as pd, json
processed = repo_root / 'data' / 'processed'
display(pd.read_csv(processed / '21d_empirical_headline.csv'))
display(pd.read_csv(processed / '21d_locked_holdout_model_table.csv'))
display(pd.read_csv(processed / '21d_primary_robustness_table.csv').head(20))
display(pd.read_csv(processed / '21d_integrity_checks.csv'))
print(json.loads((processed / '21d_manifest.json').read_text()))

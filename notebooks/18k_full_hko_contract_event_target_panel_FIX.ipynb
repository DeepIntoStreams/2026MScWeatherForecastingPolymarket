# %% [markdown]
# # 18k full HKO contract-event target panel FIX
#
# This fixed notebook runs the repaired 18k script. It avoids the pandas nullable-integer markdown-table error and works from either the repo root or `notebooks/`.

# %%
from pathlib import Path
import os
p = Path.cwd().resolve()
if p.name == 'notebooks':
    os.chdir(p.parent)
print('Working directory:', Path.cwd().resolve())

# %%
# %run scripts/18k_full_hko_contract_event_target_panel_FIX.py

# %%
from IPython.display import FileLink, display
from pathlib import Path
zip_path = Path('data/review_bundles/18k_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))

# %% [markdown]
# # 18m full HKO market-only baseline diagnostics
#
# This notebook runs the 18m script from the repository root. It produces supervisor-ready market-only score summaries, event-book diagnostics, figures, and a review bundle zip.

# %%
from pathlib import Path
import os

p = Path.cwd().resolve()
if p.name == 'notebooks':
    os.chdir(p.parent)
print('Working directory:', Path.cwd().resolve())

# %%
# %run scripts/18m_full_hko_market_only_baseline_diagnostics.py

# %%
from IPython.display import FileLink, display
from pathlib import Path

zip_path = Path('data/review_bundles/18m_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))

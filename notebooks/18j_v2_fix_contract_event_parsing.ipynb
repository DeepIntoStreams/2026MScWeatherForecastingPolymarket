# %% [markdown]
# # 18j v2 contract-event parsing fix
#
# This notebook fixes the 18j parsing errors: event date is parsed from the market slug/question, and Celsius boundaries are parsed from visible contract labels rather than `groupItemThreshold`. It produces a repaired full HKO contract-event universe and a review bundle zip.

# %%
# %run ../scripts/18j_v2_fix_contract_event_parsing.py

# %%
from IPython.display import FileLink, display
from pathlib import Path
zip_path = Path('../data/review_bundles/18j_v2_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))

# %% [markdown]
# After running all cells, download `18j_v2_review_bundle.zip` and upload it to ChatGPT for inspection.

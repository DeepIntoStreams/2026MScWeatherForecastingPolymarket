# %% [markdown]
# # 18i Hong Kong empirical baseline reporting\n\nThis notebook runs the 18i reporting script. It consolidates the successful 18f official HKO/Polymarket panel and 18h narrow-window CLOB recovery into dissertation-facing tables, figures and a markdown report.\n\nMain sample: `empirical_role = formally_certified_upper_tail_threshold`.

# %%
from pathlib import Path\nimport runpy\n\nscript = Path('scripts/18i_hko_empirical_baseline_reporting.py')\nif not script.exists():\n    raise FileNotFoundError(f'Missing script: {script}')\n\nrunpy.run_path(str(script), run_name='__main__')\n

# %% [markdown]
# After execution, inspect:\n\n- `docs/research_outputs/18i_hko_empirical_baseline_report.md`\n- `data/processed/18i_hko_main_market_only_score_summary.csv`\n- `data/processed/18i_hko_main_scoring_panel_formally_certified.csv`\n- `figures/reports/18i_hko_market_brier_by_decision_rule.png`\n- `figures/reports/18i_hko_market_log_score_by_decision_rule.png`

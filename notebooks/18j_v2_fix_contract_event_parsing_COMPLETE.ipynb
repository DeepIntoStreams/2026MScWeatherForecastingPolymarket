# %% [markdown]
# # 18j v2 complete contract-event parsing fix
#
# Run the cell below. It automatically moves to the repository root if the notebook is opened from `notebooks/`, runs the repaired script, and then shows a download link for the review bundle.

# %%
from pathlib import Path
import os

cwd = Path.cwd().resolve()
print('Starting cwd:', cwd)

# Jupyter often starts inside notebooks/. Move one level up to the repo root.
if cwd.name == 'notebooks':
    os.chdir(cwd.parent)

print('Running from:', Path.cwd().resolve())
print('Input audit exists:', Path('data/processed/18j_gamma_metadata_settlement_family_audit.csv').exists())
print('Script exists:', Path('scripts/18j_v2_fix_contract_event_parsing_COMPLETE.py').exists())

# %%
# %run scripts/18j_v2_fix_contract_event_parsing_COMPLETE.py

# %%
from IPython.display import FileLink, display
from pathlib import Path

zip_path = Path('data/review_bundles/18j_v2_review_bundle.zip')
print('Zip exists:', zip_path.exists())
print('Zip path:', zip_path.resolve())

if zip_path.exists():
    display(FileLink(str(zip_path)))
else:
    print('The zip was not created. Scroll up and inspect the error above.')

# %% [markdown]
# # 18l full HKO contract-event CLOB price recovery
#
# This notebook runs the terminal-first 18l script. It recovers no-lookahead CLOB prices for the full 803-row HKO contract-event target panel.

# %%
from pathlib import Path
import os

p = Path.cwd().resolve()
if p.name == 'notebooks':
    os.chdir(p.parent)
print('Working directory:', Path.cwd().resolve())
# Out:
# Working directory: /Users/edwardlee/Desktop/2026MScWeatherForecastingPolymarket

# %%
# %run scripts/18l_full_hko_contract_event_clob_price_recovery.py
# Out:
# Repository root: /Users/edwardlee/Desktop/2026MScWeatherForecastingPolymarket
# Output raw price cache: data/raw/polymarket_clob_price_history_18l
# Lookback hours: 168
# Loaded 18k target panel: (803, 61)
# 18l admissible target rows with YES token: 803
# CLOB contracts to retrieve: 803
#   retrieved 25/803 contracts; non-empty histories=25
#   retrieved 50/803 contracts; non-empty histories=50
#   retrieved 75/803 contracts; non-empty histories=75
#   retrieved 100/803 contracts; non-empty histories=100
#   retrieved 125/803 contracts; non-empty histories=125
#   retrieved 150/803 contracts; non-empty histories=150
#   retrieved 175/803 contracts; non-empty histories=175
#   retrieved 200/803 contracts; non-empty histories=200
#   retrieved 225/803 contracts; non-empty histories=225
#   retrieved 250/803 contracts; non-empty histories=250
#   retrieved 275/803 contracts; non-empty histories=275
#   retrieved 300/803 contracts; non-empty histories=300
#   retrieved 325/803 contracts; non-empty histories=325
#   retrieved 350/803 contracts; non-empty histories=330
#   retrieved 375/803 contracts; non-empty histories=353
#   retrieved 400/803 contracts; non-empty histories=378
#   retrieved 425/803 contracts; non-empty histories=403
#   retrieved 450/803 contracts; non-empty histories=428
#   retrieved 475/803 contracts; non-empty histories=451
#   retrieved 500/803 contracts; non-empty histories=467
#   retrieved 525/803 contracts; non-empty histories=492
#   retrieved 550/803 contracts; non-empty histories=517
#   retrieved 575/803 contracts; non-empty histories=539
#   retrieved 600/803 contracts; non-empty histories=550
#   retrieved 625/803 contracts; non-empty histories=570
#   retrieved 650/803 contracts; non-empty histories=595
#   retrieved 675/803 contracts; non-empty histories=620
#   retrieved 700/803 contracts; non-empty histories=645
#   retrieved 725/803 contracts; non-empty histories=670
#   retrieved 750/803 contracts; non-empty histories=695
#   retrieved 775/803 contracts; non-empty histories=720
#   retrieved 800/803 contracts; non-empty histories=745
#   retrieved 803/803 contracts; non-empty histories=748
#
# Saved outputs:
#   data/processed/18l_full_hko_contract_event_price_history_panel.csv (13,974,745 bytes)
#   data/processed/18l_full_hko_contract_event_no_lookahead_decision_panel.csv (161,683,267 bytes)
#   data/processed/18l_full_hko_contract_event_market_scoring_panel.csv (161,810,805 bytes)
#   data/processed/18l_full_hko_contract_event_market_score_summary.csv (2,004 bytes)
#   data/processed/18l_full_hko_contract_event_book_snapshot_summary.csv (27,579 bytes)
#   data/processed/18l_clob_recovery_diagnostics.csv (268,786 bytes)
#   data/processed/18l_clob_recovery_integrity_checks.csv (509 bytes)
#   data/processed/18l_clob_recovery_issues.csv (86,269 bytes)
#   docs/research_outputs/18l_full_hko_contract_event_clob_price_recovery_report.md (39,071 bytes)
#   data/review_bundles/18l_review_bundle.zip (30,620,455 bytes)
#
# 18l complete. Upload data/review_bundles/18l_review_bundle.zip for inspection.

# %%
from IPython.display import FileLink, display
from pathlib import Path

zip_path = Path('data/review_bundles/18l_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))
# Out:
# Zip exists: True /Users/edwardlee/Desktop/2026MScWeatherForecastingPolymarket/data/review_bundles/18l_review_bundle.zip
# /Users/edwardlee/Desktop/2026MScWeatherForecastingPolymarket/data/review_bundles/18l_review_bundle.zip

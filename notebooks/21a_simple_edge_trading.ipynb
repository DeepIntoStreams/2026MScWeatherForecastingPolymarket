# %% [markdown]
# # 21a simple edge trading — clean replacement
#
# This notebook runs the clean, reproducible 21a script.

# %%
from pathlib import Path
import subprocess, sys
cwd=Path.cwd().resolve()
repo=cwd.parent if cwd.name=='notebooks' else cwd
subprocess.run([sys.executable,str(repo/'scripts'/'21a_simple_edge_trading.py'),'--repo-root',str(repo),'--thresholds','0,0.02,0.05,0.10','--primary-threshold','0.05','--trade-cost','0'],check=True)

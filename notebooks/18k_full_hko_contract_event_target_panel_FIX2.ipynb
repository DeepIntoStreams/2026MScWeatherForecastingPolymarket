# %% [markdown]
# # 18k full HKO contract-event target panel FIX2
#
# This notebook runs the corrected 18k script. The fix uses the joined realised HKO value after merge (`hko_tmax_C_hko`) rather than the blank metadata field from 18j v2.

# %%
from pathlib import Path
import os
p = Path.cwd().resolve()
if p.name == 'notebooks':
    os.chdir(p.parent)
print('Working directory:', Path.cwd().resolve())

# %%
# %run scripts/18k_full_hko_contract_event_target_panel_FIX2.py

# %%
from IPython.display import FileLink, display
from pathlib import Path
zip_path = Path('data/review_bundles/18k_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))

# %% [markdown]
# # 19b common-support market versus ECMWF proxy comparison
#
# Terminal execution is preferred. This notebook is a backup runner only.

# %%
from pathlib import Path
import os
p = Path.cwd().resolve()
if p.name == 'notebooks':
    os.chdir(p.parent)
print('Working directory:', Path.cwd().resolve())

# %%
# %run scripts/19b_common_support_market_vs_ecmwf_proxy_comparison.py

# %%
from IPython.display import FileLink, display
from pathlib import Path
zip_path = Path('data/review_bundles/19b_review_bundle.zip')
print('Zip exists:', zip_path.exists(), zip_path.resolve())
if zip_path.exists():
    display(FileLink(str(zip_path)))

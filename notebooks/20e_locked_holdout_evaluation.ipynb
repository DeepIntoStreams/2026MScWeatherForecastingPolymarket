# %% [markdown]
# # 20e single locked final chronological holdout evaluation
#
# This notebook wraps the Terminal-ready 20e script. It performs the first and only evaluation on the frozen final holdout.

# %%
from pathlib import Path
import subprocess, sys
cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == 'notebooks' else cwd
script = repo_root / 'scripts' / '20e_locked_holdout_evaluation.py'
cmd = [sys.executable, str(script), '--repo-root', str(repo_root), '--bootstrap-reps', '10000', '--random-seed', '20260715']
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)

# %%
import pandas as pd, json
processed = repo_root / 'data' / 'processed'
display(pd.read_csv(processed / '20e_locked_holdout_integrity_checks.csv'))
display(pd.read_csv(processed / '20e_locked_holdout_binary_score_summary.csv'))
display(pd.read_csv(processed / '20e_locked_holdout_event_book_score_summary.csv'))
print(json.loads((processed / '20e_locked_holdout_manifest.json').read_text()))

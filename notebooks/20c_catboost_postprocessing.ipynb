# %% [markdown]
# # 20c compact CatBoost post-processing — corrected version
#
# This replaces the earlier 20c script. It retains all four direct probability benchmarks using robust column-name resolution, cleans the ranking table, and leaves the final chronological holdout sealed.

# %%
from pathlib import Path
import subprocess, sys
cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == 'notebooks' else cwd
script = repo_root / 'scripts' / '20c_catboost_postprocessing.py'
cmd = [sys.executable, str(script), '--repo-root', str(repo_root), '--bootstrap-reps', '5000', '--random-seed', '20260715']
print('Running:', ' '.join(cmd))
subprocess.run(cmd, check=True)

# %%
import pandas as pd, json
processed = repo_root / 'data' / 'processed'
display(pd.read_csv(processed / '20c_integrity_checks.csv'))
display(pd.read_csv(processed / '20c_model_specification_ranking.csv'))
display(pd.read_csv(processed / '20c_selected_model_benchmark_summary.csv'))
print(json.loads((processed / '20c_selected_model_manifest.json').read_text()))
